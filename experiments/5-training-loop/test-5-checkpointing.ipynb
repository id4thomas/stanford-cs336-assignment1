# %%
import torch

# %%
fpath = "../../results/model/tinystories-run2/best_step_8800.pt"
state_dict = torch.load(fpath)

# %%
model_dict = state_dict['model']

# %%
# has '_orig_mod' due to being compiled
# model = torch.compile(model, backend="aot_eager")
# model_dict.keys() # '_orig_mod.token_embeddings.weight', '_orig_mod.layers.0.ln1.weight'
# Out:
# odict_keys(['_orig_mod.token_embeddings.weight', '_orig_mod.layers.0.ln1.weight', '_orig_mod.layers.0.ln2.weight', '_orig_mod.layers.0.attn.q_proj.weight', '_orig_mod.layers.0.attn.k_proj.weight', '_orig_mod.layers.0.attn.v_proj.weight', '_orig_mod.layers.0.attn.output_proj.weight', '_orig_mod.layers.0.ffn.w1.weight', '_orig_mod.layers.0.ffn.w2.weight', '_orig_mod.layers.0.ffn.w3.weight', '_orig_mod.layers.1.ln1.weight', '_orig_mod.layers.1.ln2.weight', '_orig_mod.layers.1.attn.q_proj.weight', '_orig_mod.layers.1.attn.k_proj.weight', '_orig_mod.layers.1.attn.v_proj.weight', '_orig_mod.layers.1.attn.output_proj.weight', '_orig_mod.layers.1.ffn.w1.weight', '_orig_mod.layers.1.ffn.w2.weight', '_orig_mod.layers.1.ffn.w3.weight', '_orig_mod.layers.2.ln1.weight', '_orig_mod.layers.2.ln2.weight', '_orig_mod.layers.2.attn.q_proj.weight', '_orig_mod.layers.2.attn.k_proj.weight', '_orig_mod.layers.2.attn.v_proj.weight', '_orig_mod.layers.2.attn.output_proj.weight', '_orig_mod.layers.2.ffn.w1.w
# ...

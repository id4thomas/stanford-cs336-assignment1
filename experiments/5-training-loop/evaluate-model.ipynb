# %%
import json
import os
import sys

prj_path = os.path.dirname(os.path.dirname(os.getcwd()))
# sys.path.append(os.path.join(prj_path, "cs336_basics"))
# sys.path.append(prj_path)
os.chdir(prj_path)
from cs336_basics.tokenizer.bpe import BPETokenizer
from cs336_basics.model import Transformer
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[4], line 9
#       6 # sys.path.append(os.path.join(prj_path, "cs336_basics"))
#       7 # sys.path.append(prj_path)
#       8 os.chdir(prj_path)
# ----> 9 from cs336_basics.tokenizer.bpe import BPETokenizer
#      10 from cs336_basics.model import Transformer
#
# File ~/github/stanford-cs336/stanford-cs336-assignment1/cs336_basics/__init__.py:3
#       1 import importlib.metadata
# ----> 3 __version__ = importlib.metadata.version("cs336_basics")
#
# File /opt/miniconda3/envs/hf/lib/python3.10/importlib/metadata/__init__.py:996, in version(distribution_name)
#     989 def version(distribution_name):
#     990     """Get the version string for the named package.
#     991
#     992     :param distribution_name: The name of the distribution package to query.
# ...

# %%
run_name = "tinystories-run1"
config_dir = f"../../configs/{run_name}.json"

with open(config_dir, 'r') as f:
    config = json.load(f)

# %%
def initialize_model(
    config,
    device=None,
    dtype=None
):
    model = Transformer(
        vocab_size=config['vocab_size'],
        context_length=config['context_length'],
        d_model=config['d_model'],
        num_layers=config['num_layers'],
        num_heads=config['num_heads'],
        d_ff=config['d_ff'],
        rope_theta=config['rope_theta'],
        device=device,
        dtype=dtype
    )
    return model
